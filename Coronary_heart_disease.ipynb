# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib

# %%
df=pd.read_csv('cad.csv')

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df.rename(columns = {'TenYearCHD':'chd'}, inplace = True)
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    chd
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0

# %%
nadf=df[df['glucose'].isna()]
nadf
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 14       0   39        2.0              1         9.0     0.0
# 21       0   43        1.0              0         0.0     0.0
# 26       0   60        1.0              0         0.0     0.0
# 42       0   52        1.0              0         0.0     1.0
# 54       0   39        2.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4170     0   41        2.0              1         5.0     0.0
# 4208     0   51        1.0              1         9.0     0.0
# 4229     0   51        3.0              1        20.0     0.0
# 4230     0   56        1.0              1         3.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 14                  0             0         0    226.0  114.0   64.0  22.35
# ...

# %%
mean=df['glucose'].mean()
mean
# Out:
# 81.96675324675324

# %%
df['glucose'].fillna(mean, inplace=True)

# %%
madf=df[df['cigsPerDay'].isna()]
madf
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 131      1   43        4.0              1         NaN     0.0
# 139      1   49        4.0              1         NaN     0.0
# 1046     0   49        1.0              1         NaN     0.0
# 1292     1   42        3.0              1         NaN     0.0
# 1347     0   58        4.0              1         NaN     0.0
# 1451     1   54        1.0              1         NaN     0.0
# 1497     1   55        1.0              1         NaN     0.0
# 1610     0   61        1.0              1         NaN     0.0
# 1625     0   49        2.0              1         NaN     0.0
# 1870     0   47        2.0              1         NaN     0.0
# 1963     1   45        3.0              1         NaN     0.0
# 1980     0   60        2.0              1         NaN     0.0
# 2405     0   49        1.0              1         NaN     0.0
# 2513     1   42        1.0              1         NaN     0.0
# ...

# %%
mean=df['cigsPerDay'].mean()
df['cigsPerDay'].fillna(mean, inplace=True)

# %%
mean=df['education'].mean()
df['education'].fillna(mean, inplace=True)
madf=df[df['education'].isna()]
madf
# Out:
# Empty DataFrame
# Columns: [male, age, education, currentSmoker, cigsPerDay, BPMeds, prevalentStroke, prevalentHyp, diabetes, totChol, sysBP, diaBP, BMI, heartRate, glucose, chd]
# Index: []

# %%
madf=df[df['age'].isna()]
madf
# Out:
# Empty DataFrame
# Columns: [male, age, education, currentSmoker, cigsPerDay, BPMeds, prevalentStroke, prevalentHyp, diabetes, totChol, sysBP, diaBP, BMI, heartRate, glucose, chd]
# Index: []

# %%
mean=df['totChol'].mean()
df['totChol'].fillna(mean, inplace=True)
madf=df[df['totChol'].isna()]
madf
# Out:
# Empty DataFrame
# Columns: [male, age, education, currentSmoker, cigsPerDay, BPMeds, prevalentStroke, prevalentHyp, diabetes, totChol, sysBP, diaBP, BMI, heartRate, glucose, chd]
# Index: []

# %%
mean=df['BMI'].mean()
df['BMI'].fillna(mean, inplace=True)
madf=df[df['BMI'].isna()]
madf
# Out:
# Empty DataFrame
# Columns: [male, age, education, currentSmoker, cigsPerDay, BPMeds, prevalentStroke, prevalentHyp, diabetes, totChol, sysBP, diaBP, BMI, heartRate, glucose, chd]
# Index: []

# %%
mean=df['heartRate'].mean()
df['heartRate'].fillna(mean, inplace=True)
madf=df[df['heartRate'].isna()]
madf
# Out:
# Empty DataFrame
# Columns: [male, age, education, currentSmoker, cigsPerDay, BPMeds, prevalentStroke, prevalentHyp, diabetes, totChol, sysBP, diaBP, BMI, heartRate, glucose, chd]
# Index: []

# %%
df.dropna(subset=["BPMeds"], inplace=True)

# %%
nadf=df[df['male'].isna()]
nadf
# Out:
# Empty DataFrame
# Columns: [male, age, education, currentSmoker, cigsPerDay, BPMeds, prevalentStroke, prevalentHyp, diabetes, totChol, sysBP, diaBP, BMI, heartRate, glucose, chd]
# Index: []

# %%
x=df.copy()
target=df['chd']
x.drop(columns=['chd'], inplace=True)
x
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df=df.drop(['education'], axis=1)

# %%
df.head()
# Out:
#    male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39              0         0.0     0.0                0
# 1     0   46              0         0.0     0.0                0
# 2     1   48              1        20.0     0.0                0
# 3     0   61              1        30.0     0.0                0
# 4     0   46              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    chd
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0

# %%
df['cigsPerDay'] = df['cigsPerDay'].astype(int)
df.head()
# Out:
#    male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39              0           0     0.0                0
# 1     0   46              0           0     0.0                0
# 2     1   48              1          20     0.0                0
# 3     0   61              1          30     0.0                0
# 4     0   46              1          23     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    chd
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0

# %%
df['BPMeds'] = df['BPMeds'].astype(int)
df.head()
# Out:
#    male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39              0           0       0                0
# 1     0   46              0           0       0                0
# 2     1   48              1          20       0                0
# 3     0   61              1          30       0                0
# 4     0   46              1          23       0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    chd
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0

# %%
z=df.copy()
target2=df['chd']
z.drop(columns=['chd'], inplace=True)
z
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0           0       0                0
# 1        0   46              0           0       0                0
# 2        1   48              1          20       0                0
# 3        0   61              1          30       0                0
# 4        0   46              1          23       0                0
# ...    ...  ...            ...         ...     ...              ...
# 4232     1   68              0           0       0                0
# 4233     1   50              1           1       0                0
# 4234     1   51              1          43       0                0
# 4236     0   44              1          15       0                0
# 4237     0   52              0           0       0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# ...

# %%
madf=x[x['glucose'].isna()]
madf
# Out:
# Empty DataFrame
# Columns: [male, age, education, currentSmoker, cigsPerDay, BPMeds, prevalentStroke, prevalentHyp, diabetes, totChol, sysBP, diaBP, BMI, heartRate, glucose]
# Index: []

# %%
target
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4232    1
# 4233    1
# 4234    0
# 4236    0
# 4237    0
# Name: chd, Length: 4185, dtype: int64

# %%
target2
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4232    1
# 4233    1
# 4234    0
# 4236    0
# 4237    0
# Name: chd, Length: 4185, dtype: int64

# %%
z.isnull().values.any()
# Out:
# False

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(z,target2,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.svm import SVC
model2=SVC()
model2.fit(x_train,y_train)
# Out:
# SVC()

# %%
from sklearn.ensemble import RandomForestClassifier
model3=RandomForestClassifier()
model3.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model3.score(x_test,y_test)
# Out:
# 0.8542413381123058

# %%
model2.score(x_test,y_test)
# Out:
# 0.8446833930704899

# %%
model.score(x_test,y_test)
# Out:
# 0.8494623655913979

# %%
test=[1,75,0,20,1,1,1,0,255,150,97,28.97,50,98]
model.predict([test])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
import pickle

# %%
with open('Detect_model.pickle','wb') as f:
    pickle.dump(model,f)

# %%
# sex: **male or female;(Nominal)

# age: age of the patient;(Continuous - Although the recorded ages have been truncated to whole numbers, the concept of age is continuous)
# Behavioural

# **currentSmoker: **whether or not the patient is a current smoker (Nominal)

# cigsPerDay: the number of cigarettes that the person smoked on average in one day.(can be considered continuous as one can have any number of cigarretts, even half a cigarette.)

# Medical( history):

# BPMeds: whether or not the patient was on blood pressure medication (Nominal)

# prevalentStroke: whether or not the patient had previously had a stroke (Nominal)

# ****prevalentHyp: whether or not the patient was hypertensive (Nominal)

# diabetes: whether or not the patient had diabetes (Nominal)

# Medical(current):

# totChol: total cholesterol level (Continuous)

# sysBP: systolic blood pressure (Continuous)

# **diaBP: **diastolic blood pressure (Continuous)

# BMI: Body Mass Index (Continuous)

# heartRate: heart rate (Continuous - In medical research, variables such as heart rate though in fact discrete, yet are considered continuous because of large number of possible values.)

# glucose: glucose level (Continuous)

# Predict variable (desired target):

# 10 year risk of coronary heart disease CHD (binary: “1”, means “Yes”, “0” means “No”)

# %%
test=[1,75,3,1,20,0,0,0,0,255,150,97,28.97,50,98]
model3.predict([test])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
